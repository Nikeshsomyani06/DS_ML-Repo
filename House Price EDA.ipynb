# %% [markdown]
#  EDA Steps to Follow :-
# a) Identification of variables and data types
# b) Descriptive Statistics
# c) Missing value treatment
# d) Variable transformations ,Binning, Scaling/Normalization
# e) Correlation
#
# Now lets gets our hand dirty by applying exploratory data analysis and trying to get some insights about our dataset of house features and its sales prices

# %% [markdown]
# # Import libraries
# pandas: Used for storing and playing with data using DataFrame.
# numpy: Used for working with arrays in python.
# matplotlib, seaborn: Used for plotting graphs from data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.max_open_warning': 0})

# %% [markdown]
# # Loading the data set - Reading CSV files

# %%
data = pd.read_csv('train.csv')

# %% [markdown]
# # Identification of variables and data types
# In this step, we will check what the data set comprises of. We will execute the below commands on the data
#
# a) head of the dataset
#
# b) tail of the dataset
#
# c) the shape of the dataset
#
# d) columns in the dataset
#
# e) Identify Predictor (Input) and Target (output) variables
#
# f) datatype of columns in the dataset
# info of the dataset

# %%
# Top 5 rows of dataset
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
# end 5 rows of dataset
data.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [5 rows x 81 columns]

# %% [markdown]
# The shape tells us a number of data records/rows and variables/features we have in the data set.
#
# Size - df.size => Return an int representing the number of elements in this object.
# Shape - df.shape => Return a tuple representing the dimensionality of the DataFrame.
# This helps you to know the dimensions of the data!!!!

# %%
print("Size of data: ", data.size)
print("Shape of data: ", data.shape)
print('There are {} data items with {} features \n \n '.format(data.shape[0], data.shape[1]))
# Out:
# Size of data:  118260
# Shape of data:  (1460, 81)
# There are 1460 data items with 81 features

# %%
# Columns of Dataset
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
# Column datatypes
data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
#Summary 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %% [markdown]
# Variable Types
# Variable are of different types
#
# Numerical
# Categorical

# %%
# find numerical variables
numerical = [var for var in data.columns if data[var].dtype!='O']
print('There are {} numerical variables'.format(len(numerical)))
# Out:
# There are 38 numerical variables

# %% [markdown]
# #Numerical
# #Numerical variables can be
#
# #1 binary
# #2 continuous
# #3 discrete

# %%
# we have following numerical features with unique values
for var in numerical:
    print(var, " => unique count =",len(data[var].unique()))
# Out:
# Id  => unique count = 1460
# MSSubClass  => unique count = 15
# LotFrontage  => unique count = 111
# LotArea  => unique count = 1073
# OverallQual  => unique count = 10
# OverallCond  => unique count = 9
# YearBuilt  => unique count = 112
# YearRemodAdd  => unique count = 61
# MasVnrArea  => unique count = 328
# BsmtFinSF1  => unique count = 637
# BsmtFinSF2  => unique count = 144
# BsmtUnfSF  => unique count = 780
# TotalBsmtSF  => unique count = 721
# 1stFlrSF  => unique count = 753
# 2ndFlrSF  => unique count = 417
# LowQualFinSF  => unique count = 24
# GrLivArea  => unique count = 861
# BsmtFullBath  => unique count = 4
# BsmtHalfBath  => unique count = 3
# FullBath  => unique count = 4
# HalfBath  => unique count = 3
# BedroomAbvGr  => unique count = 8
# KitchenAbvGr  => unique count = 4
# TotRmsAbvGrd  => unique count = 12
# Fireplaces  => unique count = 4
# GarageYrBlt  => unique count = 98
# GarageCars  => unique count = 5
# GarageArea  => unique count = 441
# WoodDeckSF  => unique count = 274
# OpenPorchSF  => unique count = 202
# EnclosedPorch  => unique count = 120
# 3SsnPorch  => unique count = 20
# ScreenPorch  => unique count = 76
# PoolArea  => unique count = 8
# MiscVal  => unique count = 21
# MoSold  => unique count = 12
# YrSold  => unique count = 5
# SalePrice  => unique count = 663

# %%
# Do we have discrte variables....... amoung numerical variables?
discrete = []
for var in numerical:
    if len(data[var].unique())<20:
        discrete.append(var)
        print(var , ' is discrete with unique count ' , len(data[var].unique()), ' => ', data[var].unique())
        
print('There are {} discrete variables'.format(len(discrete)))

# These discrete variables selectively should be handled differently than continous variables or numeric variable, 
# if by domain knowledge they are actually categorical example OverAllQual - is a rating 1 to 10
# Out:
# MSSubClass  is discrete with unique count  15  =>  [ 60  20  70  50 190  45  90 120  30  85  80 160  75 180  40]
# OverallQual  is discrete with unique count  10  =>  [ 7  6  8  5  9  4 10  3  1  2]
# OverallCond  is discrete with unique count  9  =>  [5 8 6 7 4 2 3 9 1]
# BsmtFullBath  is discrete with unique count  4  =>  [1 0 2 3]
# BsmtHalfBath  is discrete with unique count  3  =>  [0 1 2]
# FullBath  is discrete with unique count  4  =>  [2 1 3 0]
# HalfBath  is discrete with unique count  3  =>  [1 0 2]
# BedroomAbvGr  is discrete with unique count  8  =>  [3 4 1 2 0 5 6 8]
# KitchenAbvGr  is discrete with unique count  4  =>  [1 2 3 0]
# TotRmsAbvGrd  is discrete with unique count  12  =>  [ 8  6  7  9  5 11  4 10 12  3  2 14]
# Fireplaces  is discrete with unique count  4  =>  [0 1 2 3]
# GarageCars  is discrete with unique count  5  =>  [2 3 1 0 4]
# PoolArea  is discrete with unique count  8  =>  [  0 512 648 576 555 480 519 738]
# MoSold  is discrete with unique count  12  =>  [ 2  5  9 12 10  8 11  4  1  7  3  6]
# YrSold  is discrete with unique count  5  =>  [2008 2007 2006 2009 2010]
# There are 15 discrete variables

# %%
# Identify continuous variables
continuous = [var for var in numerical if var not in discrete and var not in ['Id', 'SalePrice']]
print('There are {} continuous variables'.format(len(continuous)))
continuous
# Out:
# There are 21 continuous variables
# ['LotFrontage',
#  'LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'GarageYrBlt',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'MiscVal']

# %% [markdown]
# Categorical Variables
# Categorical variables can also be nominal or ordinal.
#
# Nominal data has no intrinsic ordering to the categories. For example gender (Male, Female, Other) has no specific ordering.
#
# Ordinal data as clear ordering such as three settings on a toaster (high medium and low).

# %%
# find categorical variables
categorical = [var for var in data.columns if data[var].dtype=='O']
print('There are {} categorical variables'.format(len(categorical)))
# Out:
# There are 43 categorical variables

# %%
for var in categorical:
    print(var, " => unique count =",len(data[var].unique())," => unique set = ", data[var].unique(), "\n")
# Out:
# MSZoning  => unique count = 5  => unique set =  ['RL' 'RM' 'C (all)' 'FV' 'RH']
#
# Street  => unique count = 2  => unique set =  ['Pave' 'Grvl']
#
# Alley  => unique count = 3  => unique set =  [nan 'Grvl' 'Pave']
#
# LotShape  => unique count = 4  => unique set =  ['Reg' 'IR1' 'IR2' 'IR3']
#
# LandContour  => unique count = 4  => unique set =  ['Lvl' 'Bnk' 'Low' 'HLS']
#
# Utilities  => unique count = 2  => unique set =  ['AllPub' 'NoSeWa']
#
# LotConfig  => unique count = 5  => unique set =  ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
#
# LandSlope  => unique count = 3  => unique set =  ['Gtl' 'Mod' 'Sev']
#
# Neighborhood  => unique count = 25  => unique set =  ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
#
# Condition1  => unique count = 9  => unique set =  ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
#
# Condition2  => unique count = 8  => unique set =  ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']
#
# BldgType  => unique count = 5  => unique set =  ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
#
# HouseStyle  => unique count = 8  => unique set =  ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
#
# RoofStyle  => unique count = 6  => unique set =  ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
#
# RoofMatl  => unique count = 8  => unique set =  ['CompShg' 'WdShngl' 'Metal' 'WdShake' 'Membran' 'Tar&Grv' 'Roll'
#  'ClyTile']
#
# Exterior1st  => unique count = 15  => unique set =  ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'AsbShng' 'Stucco' 'BrkComm' 'AsphShn' 'Stone' 'ImStucc'
#  'CBlock']
#
# Exterior2nd  => unique count = 16  => unique set =  ['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood' 'Wd Sdng' 'CmentBd'
#  'BrkFace' 'Stucco' 'AsbShng' 'Brk Cmn' 'ImStucc' 'AsphShn' 'Stone'
#  'Other' 'CBlock']
#
# MasVnrType  => unique count = 5  => unique set =  ['BrkFace' 'None' 'Stone' 'BrkCmn' nan]
#
# ExterQual  => unique count = 4  => unique set =  ['Gd' 'TA' 'Ex' 'Fa']
#
# ExterCond  => unique count = 5  => unique set =  ['TA' 'Gd' 'Fa' 'Po' 'Ex']
#
# Foundation  => unique count = 6  => unique set =  ['PConc' 'CBlock' 'BrkTil' 'Wood' 'Slab' 'Stone']
#
# BsmtQual  => unique count = 5  => unique set =  ['Gd' 'TA' 'Ex' nan 'Fa']
#
# BsmtCond  => unique count = 5  => unique set =  ['TA' 'Gd' nan 'Fa' 'Po']
#
# BsmtExposure  => unique count = 5  => unique set =  ['No' 'Gd' 'Mn' 'Av' nan]
#
# BsmtFinType1  => unique count = 7  => unique set =  ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' nan 'LwQ']
#
# BsmtFinType2  => unique count = 7  => unique set =  ['Unf' 'BLQ' nan 'ALQ' 'Rec' 'LwQ' 'GLQ']
#
# Heating  => unique count = 6  => unique set =  ['GasA' 'GasW' 'Grav' 'Wall' 'OthW' 'Floor']
#
# HeatingQC  => unique count = 5  => unique set =  ['Ex' 'Gd' 'TA' 'Fa' 'Po']
#
# CentralAir  => unique count = 2  => unique set =  ['Y' 'N']
#
# Electrical  => unique count = 6  => unique set =  ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix' nan]
#
# KitchenQual  => unique count = 4  => unique set =  ['Gd' 'TA' 'Ex' 'Fa']
#
# Functional  => unique count = 7  => unique set =  ['Typ' 'Min1' 'Maj1' 'Min2' 'Mod' 'Maj2' 'Sev']
#
# FireplaceQu  => unique count = 6  => unique set =  [nan 'TA' 'Gd' 'Fa' 'Ex' 'Po']
#
# GarageType  => unique count = 7  => unique set =  ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan 'Basment' '2Types']
#
# GarageFinish  => unique count = 4  => unique set =  ['RFn' 'Unf' 'Fin' nan]
#
# GarageQual  => unique count = 6  => unique set =  ['TA' 'Fa' 'Gd' nan 'Ex' 'Po']
#
# GarageCond  => unique count = 6  => unique set =  ['TA' 'Fa' nan 'Gd' 'Po' 'Ex']
#
# PavedDrive  => unique count = 3  => unique set =  ['Y' 'N' 'P']
#
# PoolQC  => unique count = 4  => unique set =  [nan 'Ex' 'Fa' 'Gd']
#
# Fence  => unique count = 5  => unique set =  [nan 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']
#
# MiscFeature  => unique count = 5  => unique set =  [nan 'Shed' 'Gar2' 'Othr' 'TenC']
#
# SaleType  => unique count = 9  => unique set =  ['WD' 'New' 'COD' 'ConLD' 'ConLI' 'CWD' 'ConLw' 'Con' 'Oth']
#
# SaleCondition  => unique count = 6  => unique set =  ['Normal' 'Abnorml' 'Partial' 'AdjLand' 'Alloca' 'Family']

# %% [markdown]
# Descriptive Statistics ¶
# If we would like to get a statistical summary of each column, such as count, column mean value, column standard deviation, etc. We use the describe method:
#
# Mean: The mean is the arithmetic average, for calculating the mean just add up all of the values and divide by the number of observations in your dataset.
#
# Median: The median is the middle value. It is the value that splits the dataset in half. To find the median, order your data from smallest to largest, and then find the data point that has an equal amount of values above it and below it. The method for locating the median varies slightly depending on whether your dataset has an even or odd number of values.
#
# Mode: The mode is the value that occurs the most frequently in your data set i.e. has the highest frequency. On a bar chart, the mode is the highest bar. If the data have multiple values that are tied for occurring the most frequently, you have a multimodal distribution. If no value repeats, the data do not have a mode.
#
# Standard deviation: It measures how spread out the values in a data set are around the mean.
#
# Range - Max - Min
#
# Quartiles - 25%, 50%, 75%
#
# etc...
#
# To do so use describe method on data Note - you would get stats on numerical data only.

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
data.describe(include="all")
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
#        Alley LotShape LandContour Utilities  ...     PoolArea PoolQC  Fence  \
# count     91     1460        1460      1460  ...  1460.000000      7    281
# unique     2        4           4         2  ...          NaN      3      4
# top     Grvl      Reg         Lvl    AllPub  ...          NaN     Gd  MnPrv
# freq      50      925        1311      1459  ...          NaN      3    157
# mean     NaN      NaN         NaN       NaN  ...     2.758904    NaN    NaN
# std      NaN      NaN         NaN       NaN  ...    40.177307    NaN    NaN
# min      NaN      NaN         NaN       NaN  ...     0.000000    NaN    NaN
# 25%      NaN      NaN         NaN       NaN  ...     0.000000    NaN    NaN
# 50%      NaN      NaN         NaN       NaN  ...     0.000000    NaN    NaN
# 75%      NaN      NaN         NaN       NaN  ...     0.000000    NaN    NaN
# max      NaN      NaN         NaN       NaN  ...   738.000000    NaN    NaN
#
#        MiscFeature       MiscVal       MoSold       YrSold  SaleType  \
# count           54   1460.000000  1460.000000  1460.000000      1460
# unique           4           NaN          NaN          NaN         9
# top           Shed           NaN          NaN          NaN        WD
# freq            49           NaN          NaN          NaN      1267
# mean           NaN     43.489041     6.321918  2007.815753       NaN
# std            NaN    496.123024     2.703626     1.328095       NaN
# min            NaN      0.000000     1.000000  2006.000000       NaN
# 25%            NaN      0.000000     5.000000  2007.000000       NaN
# 50%            NaN      0.000000     6.000000  2008.000000       NaN
# 75%            NaN      0.000000     8.000000  2009.000000       NaN
# max            NaN  15500.000000    12.000000  2010.000000       NaN
#
#         SaleCondition      SalePrice
# count            1460    1460.000000
# unique              6            NaN
# top            Normal            NaN
# freq             1198            NaN
# mean              NaN  180921.195890
# std               NaN   79442.502883
# min               NaN   34900.000000
# 25%               NaN  129975.000000
# 50%               NaN  163000.000000
# 75%               NaN  214000.000000
# max               NaN  755000.000000
#
# [11 rows x 81 columns]

# %%
for var in categorical:
    print(var, "=> unique count =",len(data[var].unique()), "\n--------------------------\n", data[var].value_counts())
# Out:
# MSZoning => unique count = 5
# --------------------------
#  RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
# Street => unique count = 2
# --------------------------
#  Pave    1454
# Grvl       6
# Name: Street, dtype: int64
# Alley => unique count = 3
# --------------------------
#  Grvl    50
# Pave    41
# Name: Alley, dtype: int64
# LotShape => unique count = 4
# --------------------------
#  Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64
# LandContour => unique count = 4
# --------------------------
#  Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: LandContour, dtype: int64
# Utilities => unique count = 2
# --------------------------
#  AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64
# LotConfig => unique count = 5
# --------------------------
#  Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64
# LandSlope => unique count = 3
# --------------------------
#  Gtl    1382
# Mod      65
# Sev      13
# Name: LandSlope, dtype: int64
# Neighborhood => unique count = 25
# --------------------------
#  NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# SWISU       25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64
# Condition1 => unique count = 9
# --------------------------
#  Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: Condition1, dtype: int64
# Condition2 => unique count = 8
# --------------------------
#  Norm      1445
# Feedr        6
# Artery       2
# PosN         2
# RRNn         2
# PosA         1
# RRAn         1
# RRAe         1
# Name: Condition2, dtype: int64
# BldgType => unique count = 5
# --------------------------
#  1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64
# HouseStyle => unique count = 8
# --------------------------
#  1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: HouseStyle, dtype: int64
# RoofStyle => unique count = 6
# --------------------------
#  Gable      1141
# Hip         286
# Flat         13
# Gambrel      11
# Mansard       7
# Shed          2
# Name: RoofStyle, dtype: int64
# RoofMatl => unique count = 8
# --------------------------
#  CompShg    1434
# Tar&Grv      11
# WdShngl       6
# WdShake       5
# ClyTile       1
# Membran       1
# Metal         1
# Roll          1
# Name: RoofMatl, dtype: int64
# Exterior1st => unique count = 15
# --------------------------
#  VinylSd    515
# HdBoard    222
# MetalSd    220
# Wd Sdng    206
# Plywood    108
# CemntBd     61
# BrkFace     50
# WdShing     26
# Stucco      25
# AsbShng     20
# Stone        2
# BrkComm      2
# ImStucc      1
# CBlock       1
# AsphShn      1
# Name: Exterior1st, dtype: int64
# Exterior2nd => unique count = 16
# --------------------------
#  VinylSd    504
# MetalSd    214
# HdBoard    207
# Wd Sdng    197
# Plywood    142
# CmentBd     60
# Wd Shng     38
# Stucco      26
# BrkFace     25
# AsbShng     20
# ImStucc     10
# Brk Cmn      7
# Stone        5
# AsphShn      3
# Other        1
# CBlock       1
# Name: Exterior2nd, dtype: int64
# MasVnrType => unique count = 5
# --------------------------
#  None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64
# ExterQual => unique count = 4
# --------------------------
#  TA    906
# Gd    488
# Ex     52
# Fa     14
# Name: ExterQual, dtype: int64
# ExterCond => unique count = 5
# --------------------------
#  TA    1282
# Gd     146
# Fa      28
# Ex       3
# Po       1
# Name: ExterCond, dtype: int64
# Foundation => unique count = 6
# --------------------------
#  PConc     647
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Wood        3
# Name: Foundation, dtype: int64
# BsmtQual => unique count = 5
# --------------------------
#  TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64
# BsmtCond => unique count = 5
# --------------------------
#  TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: BsmtCond, dtype: int64
# BsmtExposure => unique count = 5
# --------------------------
#  No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64
# BsmtFinType1 => unique count = 7
# --------------------------
#  Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64
# BsmtFinType2 => unique count = 7
# --------------------------
#  Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64
# Heating => unique count = 6
# --------------------------
#  GasA     1428
# GasW       18
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# Name: Heating, dtype: int64
# HeatingQC => unique count = 5
# --------------------------
#  Ex    741
# TA    428
# Gd    241
# Fa     49
# Po      1
# Name: HeatingQC, dtype: int64
# CentralAir => unique count = 2
# --------------------------
#  Y    1365
# N      95
# Name: CentralAir, dtype: int64
# Electrical => unique count = 6
# --------------------------
#  SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64
# KitchenQual => unique count = 4
# --------------------------
#  TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: KitchenQual, dtype: int64
# Functional => unique count = 7
# --------------------------
#  Typ     1360
# Min2      34
# Min1      31
# Mod       15
# Maj1      14
# Maj2       5
# Sev        1
# Name: Functional, dtype: int64
# FireplaceQu => unique count = 6
# --------------------------
#  Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64
# GarageType => unique count = 7
# --------------------------
#  Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64
# GarageFinish => unique count = 4
# --------------------------
#  Unf    605
# RFn    422
# Fin    352
# Name: GarageFinish, dtype: int64
# GarageQual => unique count = 6
# --------------------------
#  TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: GarageQual, dtype: int64
# GarageCond => unique count = 6
# --------------------------
#  TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: GarageCond, dtype: int64
# PavedDrive => unique count = 3
# --------------------------
#  Y    1340
# N      90
# P      30
# Name: PavedDrive, dtype: int64
# PoolQC => unique count = 4
# --------------------------
#  Gd    3
# Fa    2
# Ex    2
# Name: PoolQC, dtype: int64
# Fence => unique count = 5
# --------------------------
#  MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64
# MiscFeature => unique count = 5
# --------------------------
#  Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: MiscFeature, dtype: int64
# SaleType => unique count = 9
# --------------------------
#  WD       1267
# New       122
# COD        43
# ConLD       9
# ConLI       5
# ConLw       5
# CWD         4
# Oth         3
# Con         2
# Name: SaleType, dtype: int64
# SaleCondition => unique count = 6
# --------------------------
#  Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64

# %%
corrMatrix = data.corr()
corrMatrix
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# TotalBsmtSF   -0.015415   -0.238518     0.392075  0.260833     0.537808
# 1stFlrSF       0.010496   -0.251758     0.457181  0.299475     0.476224
# 2ndFlrSF       0.005590    0.307886     0.080177  0.050986     0.295493
# LowQualFinSF  -0.044230    0.046474     0.038469  0.004779    -0.030429
# GrLivArea      0.008273    0.074853     0.402797  0.263116     0.593007
# BsmtFullBath   0.002289    0.003491     0.100949  0.158155     0.111098
# BsmtHalfBath  -0.020155   -0.002333    -0.007234
#
#                ScreenPorch  PoolArea   MiscVal    MoSold    YrSold  SalePrice
# Id                0.001330  0.057044 -0.006242  0.021172  0.000712  -0.021917
# MSSubClass       -0.026030  0.008283 -0.007683 -0.013585 -0.021407  -0.084284
# LotFrontage       0.041383  0.206167  0.003368  0.011200  0.007450   0.351799
# LotArea           0.043160  0.077672  0.038068  0.001205 -0.014261   0.263843
# OverallQual       0.064886  0.065166 -0.031406  0.070815 -0.027347   0.790982
# OverallCond       0.054811 -0.001985  0.068777 -0.003511  0.043950  -0.077856
# YearBuilt        -0.050364  0.004950 -0.034383  0.012398 -0.013618   0.522897
# YearRemodAdd     -0.038740  0.005829 -0.010286  0.021490  0.035743   0.507101
# MasVnrArea        0.061466  0.011723 -0.029815 -0.005965 -0.008201   0.477493
# BsmtFinSF1        0.062021  0.140491  0.003571 -0.015727  0.014359   0.386420
# BsmtFinSF2        0.088871  0.041709  0.004940 -0.015211  0.031706  -0.011378
# BsmtUnfSF        -0.012579 -0.035092 -0.023837  0.034888 -0.041258   0.214479
# TotalBsmtSF       0.084489  0.126053 -0.018479  0.013196 -0.014969   0.613581
# 1stFlrSF          0.088758  0.131525 -0.021096  0.031372 -0.013604   0.605852
# 2ndFlrSF          0.040606  0.081487  0.016197  0.035164 -0.028700   0.319334
# LowQualFinSF      0.026799  0.062157 -0.003793 -0.022174 -0.028921  -0.025606
# GrLivArea         0.101510  0.170205 -0.002416  0.050240 -0.036526   0.708624
# BsmtFullBath      0.023148  0.067616 -0.023047 -0.025361  0.067049   0.227122
# BsmtHalfBath      0.032121  0.020025 -0.007367  0.032873 -0.046524  -0.016844
# FullBath         -0.008106  0.049604 -0.014290  0.055872 -0.019669   0.560664
# HalfBath          0.072426  0.022381  0.001290 -0.009050 -0.010269   0.284108
# BedroomAbvGr      0.044300  0.070703  0.007767  0.046544 -0.036014   0.168213
# KitchenAbvGr     -0.051613 -0.014525  0.062341  0.026589  0.031687  -0.135907
# TotRmsAbvGrd      0.059383  0.083757  0.024763  0.036907 -0.034516   0.533723
# Fireplaces        0.184530  0.095074  0.001409  0.046357 -0.024096   0.466929
# GarageYrBlt      -0.075418 -0.014501 -0.032417  0.005337 -0.001014   0.486362
# GarageCars        0.050494  0.020934 -0.043080  0.040522 -0.039117   0.640409
# GarageArea        0.051412  0.061047 -0.027400  0.027974 -0.027378   0.623431
# WoodDeckSF       -0.074181  0.073378 -0.009551  0.021011  0.022270   0.324413
# OpenPorchSF       0.074304  0.060762 -0.018584  0.071255 -0.057619   0.315856
# EnclosedPorch    -0.082864  0.054203  0.018361 -0.028887 -0.009916  -0.128578
# 3SsnPorch        -0.031436 -0.007992  0.000354  0.029474  0.018645   0.044584
# ScreenPorch       1.000000  0.051307  0.031946  0.023217  0.010694   0.111447
# PoolArea          0.051307  1.000000  0.029669 -0.033737 -0.059689   0.092404
# MiscVal           0.031946  0.029669  1.000000 -0.006495  0.004906  -0.021190
# MoSold            0.023217 -0.033737 -0.006495  1.000000 -0.145721   0.046432
# YrSold            0.010694 -0.059689  0.004906 -0.145721  1.000000  -0.028923
# SalePrice         0.111447  0.092404 -0.021190  0.046432 -0.028923   1.000000
#
# [38 rows x 38 columns]

# %%
# Correlation with output variable SalePrice
featureCorrWithtarget = abs(corrMatrix["SalePrice"])
featureCorrWithtarget.sort_values(ascending = False)*100
# Out:
# SalePrice        100.000000
# OverallQual       79.098160
# GrLivArea         70.862448
# GarageCars        64.040920
# GarageArea        62.343144
# TotalBsmtSF       61.358055
# 1stFlrSF          60.585218
# FullBath          56.066376
# TotRmsAbvGrd      53.372316
# YearBuilt         52.289733
# YearRemodAdd      50.710097
# GarageYrBlt       48.636168
# MasVnrArea        47.749305
# Fireplaces        46.692884
# BsmtFinSF1        38.641981
# LotFrontage       35.179910
# WoodDeckSF        32.441344
# 2ndFlrSF          31.933380
# OpenPorchSF       31.585623
# HalfBath          28.410768
# LotArea           26.384335
# BsmtFullBath      22.712223
# BsmtUnfSF         21.447911
# BedroomAbvGr      16.821315
# KitchenAbvGr      13.590737
# EnclosedPorch     12.857796
# ScreenPorch       11.144657
# PoolArea           9.240355
# MSSubClass         8.428414
# OverallCond        7.785589
# MoSold             4.643225
# 3SsnPorch          4.458367
# YrSold             2.892259
# LowQualFinSF       2.560613
# Id                 2.191672
# MiscVal            2.118958
# BsmtHalfBath       1.684415
# BsmtFinSF2         1.137812
# Name: SalePrice, dtype: float64

# %% [markdown]
# # What we conclude here
#
# There's strong relation between overall quality of the houses and their sale prices.
#
# Again above grade living area seems strong indicator for sale price.
#
# Garage features, number of baths and rooms, how old the building is etc. also having effect on the price on various levels too.

# %%
#plot heat map
plt.figure(figsize=(30,30))
sns.heatmap(corrMatrix, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
top_feature = corrMatrix.index[abs(corrMatrix['SalePrice']>0.5)]
plt.subplots(figsize=(12, 8))
top_corr = data[top_feature].corr()
sns.heatmap(top_corr, annot=True)
plt.show()

# %% [markdown]
# Identify and handle Missing Value - ?, NaN, 0, “N/A”, Blank Cell
# Why missing values treatment is required? -
# Missing data in the training data set can reduce the power / fit of a model or can lead to a biased model because we have not analysed the behavior and relationship with other variables correctly. It can lead to wrong prediction or classification.
#
# Why my data has missing values? -
#
# MCAR (Missing completely at random) - if the probability of a missing data value is independent of any observation/columns in the data set, then the data are said to be missing completely at random (MCAR). There’s no relationship between whether a data point is missing and any values in the data set, missing or observed. For example MCAR is a weighing scale that ran out of batteries.
#
# MAR (Missing at random) - If the probability of being missing is the same only within groups defined by the observed data, then the data are missing at random (MAR). For example, when a weighing scale placed on a soft surface may produce more missing values than when placed on a hard surface.
#
# Missing not at random (MNAR). if the probability of a missing data value is unknown. For example, when a weighing scale goes bad and is giving missing data but is not noted.#

# %% [markdown]
# # Detetecting missing -
# Standard Missing Values - isNull detects Non-Standard Missing Values - isNull doesnt detects example XX, 9999 etc...
#
# An easy way to detect these various formats is to put them in a list. Then when we import the data, Pandas will recognize them right away. Here’s an example of how we would do that
#
# Make a list of missing value types
#
# missing_values = ["9999", "XX", "--"]
#
# df = pd.read_csv("property data.csv", na_values = missing_values)
#
# You might not be able to catch all of these right away. As you work through the data and see other types of missing values, you can add them to the list.
#
# It’s important to recognize these non-standard types of missing values for purposes of summarizing and transforming missing values.

# %%
#plot of missing value attributes
plt.figure(figsize=(12, 6))
sns.heatmap(data.isnull())
plt.show()

# %%
# Any missing values
print('Any missing values - ', data.isnull().values.any())
# Total number of missing values
print('Total number of missing values', data.isnull().sum().sum())
# Out:
# Any missing values -  True
# Total number of missing values 6965

# %%
 # Columns having all nulls
print('Columns having all nulls - ',data.isnull().all(axis=0).sum())
# Columns having at least one null
print('Columns having at least one null - ', data.isnull().any(axis=0).sum() )
# Out:
# Columns having all nulls -  0
# Columns having at least one null -  19

# %%
# Count of nulls in each row
# Number of rows having at least one missing value
print('Number of rows having at least one missing value - ', data.isnull().any(axis=1).sum())
# Number of rows with all column values null
print('Number of rows with all column values null - ', data.isnull().all(axis=1).sum())
# Out:
# Number of rows having at least one missing value -  1460
# Number of rows with all column values null -  0

# %%
total = data.isnull().sum().sort_values(ascending = False)
percent = (data.isnull().mean()*100).sort_values(ascending = False)
missingData = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missingData
# Out:
#                Total    Percent
# PoolQC          1453  99.520548
# MiscFeature     1406  96.301370
# Alley           1369  93.767123
# Fence           1179  80.753425
# FireplaceQu      690  47.260274
# ...              ...        ...
# CentralAir         0   0.000000
# SaleCondition      0   0.000000
# Heating            0   0.000000
# TotalBsmtSF        0   0.000000
# Id                 0   0.000000
#
# [81 rows x 2 columns]

# %%
missingDataFrame = (data.isnull().sum()/len(data)*100).sort_values(ascending = False).to_frame()
missingDataFrame.columns = ['count']
missingDataFrame.index.names = ['Name']
missingDataFrame['Name'] = missingDataFrame.index

plt.figure(figsize=(13, 5))
sns.set(style='whitegrid')
sns.barplot(x='Name', y='count', data=missingDataFrame)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Connect with Data Source Collection / Extraction source to load it back
#
# add Codeadd Markdown
# Fix by Dropping the column or row
# Rows could be deleted if the number of missing values are insignificant in number, as that would not impact analysis.
#
# df.dropna(axis=0, thresh=1, inplace=True)
#
# Columns could be removed if missing value are quite significant in number.
#
# #Dropping Columns with all Nulls df.dropna(axis=1, thresh=1, inplace=True)
#
# This is not suggested most times as though this is simple, as this method reduces the power of model because it reduces the sample size.
#
# It is always better to keep data than to discard it.
#
# Sometimes you can drop variables if the data is missing for more than 60% observations but only if that variable is insignificant.
#
# add Codeadd Markdown
# Fix by Imputation
# Imputation is a method to fill in the missing values with some value.
#
# The value could be
#
# Mean / Median imputation is one of the most frequently used methods for numerical columns. It consists of replacing the missing data for a given attribute by the mean or median of all known values of that variable.
# Mode/Static imputation is done for categorical columns. It is either word None/Missing/? or most frequent observation in the data set.
# Some ways are
#
# Mark it as missing or with value you feel is apt wrt the column and business domain - For the categorical columns
# Mark it as 0 or with value you feel is apt wrt the column and business domain - For the numerical columns
# Impute with mode value - For the categorical column, you can replace the missing values with mode values i.e. the frequent ones.
# Impute with mean value - For the numerical column, But before replacing with mean value, it is advisable to check that the variable shouldn’t have extreme values .i.e. outliers.
# Impute with median value - For the numerical column, In case you have extreme values such as outliers it is advisable to use the median approach.
# Imputation can be Univariate or MultiVariate

# %%
# Engineering Missing Data in categorical variables
# add label indicating 'Missing' to categorical variables
for var in categorical:
    data[var].fillna('Missing', inplace=True)

# %%
# Engineering Missing Data in numerical variables
for var in continuous:
    data[var].fillna(data[var].median(), inplace=True)

# %%
# PoolQC has missing % is 99 %. So, there is fill by Missing
data['PoolQC'] = data['PoolQC'].fillna('Missing')

# Others where missing % is above and around 50 % replace with Missing 
data['MiscFeature'] = data['MiscFeature'].fillna('Missing')
data['Alley'] = data['Alley'].fillna('Missing')
data['Fence'] = data['Fence'].fillna('Missing')
data['FireplaceQu'] = data['FireplaceQu'].fillna('Missing')

# %%
#GarageType, GarageFinish, GarageQual and GarageCond these are replacing with Missing
for col in ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']:
    data[col] = data[col].fillna('Missing')

# %%
#GarageYrBlt, GarageArea and GarageCars these are replacing with zero
for col in ['GarageYrBlt', 'GarageArea', 'GarageCars']:
    data[col] = data[col].fillna(int(0))

# %%
#BsmtFinType2, BsmtExposure, BsmtFinType1, BsmtCond, BsmtQual these are replacing with Missing
for col in ('BsmtFinType2', 'BsmtExposure', 'BsmtFinType1', 'BsmtCond', 'BsmtQual'):
    data[col] = data[col].fillna('Missing')

# %%
# Filling 'LotFrontage' according to Neighborhood. At times you fill data using alternative stategies like 
# -- imputing with median but with median of certain sub group
data['LotFrontage'] = data.groupby("Neighborhood")["LotFrontage"].transform(
    lambda x: x.fillna(x.median()))

# %%
data['MasVnrArea'] = data['MasVnrArea'].fillna(int(0))
data['MasVnrType'] = data['MasVnrType'].fillna('Missing')

# %%
data['Electrical'] = data['Electrical'].fillna(data['Electrical']).mode()[0]

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(data.isnull(), cmap='coolwarm',)

# %%
# check absence of null values
print('This House Data contains empty/NA values in', data.isnull().sum().sum(), 'cells')
# Out:
# This House Data contains empty/NA values in 0 cells

# %%
# find numerical variables
numerical = [var for var in data.columns if data[var].dtype!='O']
print('There are {} numerical variables'.format(len(numerical)))
# find categorical variables
categorical = [var for var in data.columns if data[var].dtype=='O']
print('There are {} categorical variables'.format(len(categorical)))
# Out:
# There are 38 numerical variables
# There are 43 categorical variables

# %% [markdown]
# # Variable Transformations, Binning, Normalization, Scaling,
# This involves converting data from one format to another format that may be better for analysis or better suited for processing in Machine Learning algorithms
#
# Lets look at each one by one ---
#
# add Codeadd Markdown
# Correcting Data Type
# Correcting Data Type: At times incorrect data type is assigned to column this should be fixed. Note we use df.dtype() to check data type and df.astype() to change data type

# %%
# MSSubClass is not actually number but is cat type 
data['MSSubClass'] = data['MSSubClass'].astype('object')

# %%
# find numerical variables
numerical = [var for var in data.columns if data[var].dtype!='O']
print('There are {} numerical variables'.format(len(numerical)))
# find categorical variables
categorical = [var for var in data.columns if data[var].dtype=='O']
print('There are {} categorical variables'.format(len(categorical)))
# Out:
# There are 37 numerical variables
# There are 44 categorical variables

# %% [markdown]
# # Temporal Variables¶
# Temporal Variables: ML Algorithms do not understand datetime vars, extract info like no of years or age if dob given or doj given etc…

# %%
# We have YearBuilt, YearRemodAdd etc. as Time variable -- 2003 
# if year subtracted from current year we will get better visibility of its impact on Sales Price
import datetime
now = datetime.datetime.now()
# Of above YearBuilt - can be marked and transformed in categorical as this can be grouped in buckets
data['YearBuiltAgo'] = now.year - data['YearBuilt']
data['YearBuiltAgo'].unique()
# Out:
# array([ 18,  45,  20, 106,  21,  28,  17,  48,  90,  82,  56,  16,  59,
#         15,  61,  92,  51,  54,  63,  91,  19,  53,  14,  70,  64,  94,
#        101,  55,  62,  27,  67,  68,  66,  38,  46,  24,  87,  58,  40,
#         57,  22,  49, 100,  76,  39,  23,  65,  73, 111,  26,  30,  12,
#         71,  60,  44,  36,  42, 136, 102,  31,  52,  86,  33,  50,  69,
#         85,  98,  97,  37,  95,  81,  80,  34,  35,  13, 113, 129, 105,
#         89, 103, 109,  74,  96, 121,  41,  32,  29,  72, 141,  93,  43,
#         99,  25,  11,  75, 108,  84,  79,  83,  47, 128, 107, 115, 131,
#        123, 117, 139, 146, 110, 104, 149, 116], dtype=int64)

# %% [markdown]
# # Binning¶
# Binning is a process of transforming continuous numerical variables into discrete categorical 'bins', for grouped analysis. Decision of categorization technique is based on business understanding. For example, we can categorize income in three categories, namely: High, Average and Low.

# %%
# Here we shall move the YearBuiltAgo new column into few buckets 

yearDiffBins= [0,10,25,50,80,100,200]
yearLabels = [1,2,3,4,5,6]
data['year_build_ago_group'] = pd.cut(data['YearBuiltAgo'], bins=yearDiffBins, labels=yearLabels, right=False)
data['year_build_ago_group'] = data['year_build_ago_group'].astype('object')
data['year_build_ago_group'].unique()
# Out:
# array([2, 3, 6, 5, 4], dtype=object)

# %% [markdown]
# # Scaling, Standardization, Normalizarion
# Standardization: Numerical value may be different units of measurement example kg vs lbs or currency of different countries like dollar vs Yen vs Euro
#
# Scaling is process where you transforming your data so that it fits within a specific scale, like 0-100 or 0-1. By scaling your variables, you can help compare different variables on equal footing.
#
# Normalization is the process of transforming values of several variables into a similar range/scale plus scaling the variable so the variable average is 0 and the variance is 1

# %%
# Getting Description
data['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
#histogram
sns.distplot(data['SalePrice'])

# %%
plt.hist(data['SalePrice'], color='green')
plt.show()

# %% [markdown]
# Log of a variable is a common transformation method used to change the shape of distribution of the variable on a distribution plot. It is generally used for reducing right skewness of variables.

# %%
# Normalizing the target variable
target = np.log(data['SalePrice'])
plt.hist(target, color='blue')
plt.show()

# %%
sns.distplot(target);

# %%
# find numerical variables
numerical = [var for var in data.columns if data[var].dtype!='O']
print('There are {} numerical variables'.format(len(numerical)))
# find categorical variables
categorical = [var for var in data.columns if data[var].dtype=='O']
print('There are {} categorical variables'.format(len(categorical)))
# Out:
# There are 38 numerical variables
# There are 45 categorical variables

# %% [markdown]
# # Categorical -> Numerical¶
# We have 44 categorical these at times not understood by systems, These need to be converted to numeric fields.
#
# There are various ways to do, We can use replace function or map function to replace with numeric Example below

# %%
# transform some of the categorical values to numeric ones as they are oridinal
print(data['ExterQual'].unique())

data['ExterQual'].replace("Po",1,inplace=True)

data['ExterQual'].replace("Fa",2,inplace=True)

data['ExterQual'].replace("TA",3,inplace=True)

data['ExterQual'].replace("Gd",4,inplace=True)

data['ExterQual'].replace("Ex",5,inplace=True)

print(data['ExterQual'].unique())
# Out:
# ['Gd' 'TA' 'Ex' 'Fa']
# [4 3 5 2]

# %% [markdown]
# Another way is to create dummy variables to replace the categories in a categorical variable into features of each category and represent it using 1 or 0 based on the presence or absence of the categorical value in the record.
#
# There are several different techniques which are used to encode categorical values which are
#
# pd.get_dummies - Converts categorical features into dummy variables Reference https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.get_dummies.html
#
# LabelEncoder - A function present in the scikit- learn library of python which is used to convert categorical values in numerical values. Reference https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html?highlight=label%20encoder#sklearn.preprocessing.LabelEncoder
#
# OneHotEncoder - A function present in the scikit- learn library of python which is used to convert categorical values in numerical values as a one-hot numeric array.. Reference https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html

# %%
# Lets take example to encode one or two the categorical variable. Let it be MSZoning, Street
# one-hot encoding of categorical variables using pd.get_dummies
print('Shape before hot encoding column', data.shape)
StreetEncoded = pd.get_dummies(data['Street'], prefix='Street', prefix_sep='_')
MSZoningEncoded = pd.get_dummies(data['MSZoning'], prefix='MSZoning', prefix_sep='_')
# merge with main
data = data.join(StreetEncoded)
data = data.join(MSZoningEncoded)
print('Shape before hot encoding column', data.shape)
# Out:
# Shape before hot encoding column (1460, 83)
# Shape before hot encoding column (1460, 90)

# %%
# Encode categorical variables using LabelEncoder
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
data['MSZoning'] = le.fit_transform(data['MSZoning'])
print('Shape post encoding catgrorical columns', data.shape)

# Same can be done for other also
# Out:
# Shape post encoding catgrorical columns (1460, 90)

# %%
# find numerical variables
numerical = [var for var in data.columns if data[var].dtype!='O']
print('There are {} numerical variables'.format(len(numerical)))
# find categorical variables
categorical = [var for var in data.columns if data[var].dtype=='O']
print('There are {} categorical variables'.format(len(categorical)))
# Out:
# There are 47 numerical variables
# There are 43 categorical variables

# %%
corrMatrix = data.corr()
corrMatrix
# Out:
#                         Id  MSZoning  LotFrontage   LotArea  OverallQual  \
# Id                1.000000 -0.006096    -0.009921 -0.033226    -0.028365
# MSZoning         -0.006096  1.000000    -0.105961 -0.034452    -0.160099
# LotFrontage      -0.009921 -0.105961     1.000000  0.304522     0.234812
# LotArea          -0.033226 -0.034452     0.304522  1.000000     0.105806
# OverallQual      -0.028365 -0.160099     0.234812  0.105806     1.000000
# OverallCond       0.012609  0.186951    -0.053281 -0.005636    -0.091932
# YearBuilt        -0.012713 -0.308908     0.116685  0.014228     0.572323
# YearRemodAdd     -0.021998 -0.174728     0.083348  0.013788     0.550684
# MasVnrArea       -0.051071 -0.062830     0.178469  0.103321     0.407252
# ExterQual         0.005039 -0.195689     0.165567  0.055570     0.726278
# BsmtFinSF1       -0.005024 -0.049128     0.214367  0.214103     0.239666
# BsmtFinSF2       -0.005968  0.028086     0.042463  0.111170    -0.059119
# BsmtUnfSF        -0.007940 -0.046749     0.124098 -0.002618     0.308159
# TotalBsmtSF      -0.015415 -0.087834     0.363472  0.260833     0.537808
# 1stFlrSF          0.010496 -0.055614     0.413773  0.299475     0.476224
# 2ndFlrSF            -0.099247     0.041907
# LowQualFinSF        -0.095146     0.079942
# GrLivArea            0.132936    -0.154239
# BsmtFullBath         0.146855    -0.124944
# BsmtHalfBath         0.068697    -0.044629
# FullBath             0.123634    -0.217000
# HalfBath             0.057734    -0.120295
# BedroomAbvGr         0.139264    -0.126983
# KitchenAbvGr        -0.088371     0.085912
# TotRmsAbvGrd         0.145513    -0.141793
# Fireplaces           0.227465    -0.177844
# GarageYrBlt          0.126589    -0.251828
# GarageCars           0.175167    -0.221834
# GarageArea           0.169593    -0.235580
# WoodDeckSF           0.167734    -0.135901
# OpenPorchSF         -0.044253    -0.053039
# EnclosedPorch       -0.159896     0.190614
# 3SsnPorch            0.051525    -0.038708
# ScreenPorch          0.061666    -0.033662
# PoolArea             0.035591    -0.028779
# MiscVal              0.016581    -0.006047
# MoSold              -0.003429    -0.017192
# YrSold               0.012716    -0.017131
# SalePrice            0.245063    -0.288065
# YearBuiltAgo        -0.268064     0.388683
# Street_Grvl         -0.045348     0.003127
# Street_Pave          0.045348    -0.003127
# MSZoning_C (all)    -0.160278    -0.034792
# MSZoning_FV         -0.416608    -0.090435
# MSZoning_RH         -0.203158    -0.044101
# MSZoning_RL          1.000000    -0.808585
# MSZoning_RM         -0.808585     1.000000
#
# [47 rows x 47 columns]

# %%
# Correlation with output variable
featureCorrWithtarget = abs(corrMatrix["SalePrice"])
featureCorrWithtarget.sort_values(ascending = False)*100
# Out:
# SalePrice           100.000000
# OverallQual          79.098160
# GrLivArea            70.862448
# ExterQual            68.263924
# GarageCars           64.040920
# GarageArea           62.343144
# TotalBsmtSF          61.358055
# 1stFlrSF             60.585218
# FullBath             56.066376
# TotRmsAbvGrd         53.372316
# YearBuilt            52.289733
# YearBuiltAgo         52.289733
# YearRemodAdd         50.710097
# MasVnrArea           47.261450
# Fireplaces           46.692884
# GarageYrBlt          46.675365
# BsmtFinSF1           38.641981
# LotFrontage          33.477085
# WoodDeckSF           32.441344
# 2ndFlrSF             31.933380
# OpenPorchSF          31.585623
# MSZoning_RM          28.806512
# HalfBath             28.410768
# LotArea              26.384335
# MSZoning_RL          24.506340
# BsmtFullBath         22.712223
# BsmtUnfSF            21.447911
# BedroomAbvGr         16.821315
# MSZoning             16.687220
# KitchenAbvGr         13.590737
# EnclosedPorch        12.857796
# ScreenPorch          11.144657
# MSZoning_C (all)     11.125658
# PoolArea              9.240355
# MSZoning_FV           8.994972
# OverallCond           7.785589
# MSZoning_RH           6.542929
# MoSold                4.643225
# 3SsnPorch             4.458367
# Street_Pave           4.103554
# Street_Grvl           4.103554
# YrSold                2.892259
# LowQualFinSF          2.560613
# Id                    2.191672
# MiscVal               2.118958
# BsmtHalfBath          1.684415
# BsmtFinSF2            1.137812
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corrMatrix, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
plt.figure(figsize=(30,30))
sns.heatmap(corrMatrix[(corrMatrix >= 0.5) | (corrMatrix <= -0.5)], 
            annot=True, annot_kws={"size": 8}, square=True);
plt.show()

# %%
top_feature = corrMatrix.index[abs(corrMatrix['SalePrice']>0.5)]
plt.subplots(figsize=(12, 8))
top_corr = data[top_feature].corr()
sns.heatmap(top_corr, annot=True)
plt.show()
